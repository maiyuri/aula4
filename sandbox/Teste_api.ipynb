# %%
import requests
import json

accesskey = 'efugu53u622asc77hu7h6hbq'

# def buscar_dados():
request = requests.get("https://ieeexploreapi.ieee.org/api/v1/search/articles?parameter&apikey=" + accesskey)
todos = json.loads(request.content)
print(todos)
# Out:
# {'total_records': 5785641, 'total_searched': 5785569, 'articles': [{'doi': '10.1109/CVPR.2016.90', 'title': 'Deep Residual Learning for Image Recognition', 'publisher': 'IEEE', 'isbn': '978-1-4673-8852-8', 'issn': '1063-6919', 'rank': 1, 'authors': {'authors': [{'affiliation': 'Microsoft Research', 'authorUrl': 'https://ieeexplore.ieee.org/author/37085360867', 'id': 37085360867, 'full_name': 'Kaiming He', 'author_order': 1}, {'affiliation': 'Microsoft Research', 'authorUrl': 'https://ieeexplore.ieee.org/author/37088458974', 'id': 37088458974, 'full_name': 'Xiangyu Zhang', 'author_order': 2}, {'affiliation': 'Microsoft Research', 'authorUrl': 'https://ieeexplore.ieee.org/author/37085368998', 'id': 37085368998, 'full_name': 'Shaoqing Ren', 'author_order': 3}, {'affiliation': 'Microsoft Research', 'authorUrl': 'https://ieeexplore.ieee.org/author/37407525400', 'id': 37407525400, 'full_name': 'Jian Sun', 'author_order': 4}]}, 'access_type': 'LOCKED', 'content_type': 'Conferences', 'abstra
# ...

# %%
buscar_dados
# Out:
# <function __main__.buscar_dados()>
