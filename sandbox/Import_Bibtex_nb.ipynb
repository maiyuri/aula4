# %% [markdown]
# # DATA QUALITY (Bibtex e csv)
# - Arquivo texto em formato BIBTEX
# - Objetivo: Data quality de input diversos(csv, bibtex e APIs)

# %%
import os
import pandas as pd
import re
import hashlib
import yaml
import json
import csv
import requests
from numpy import nan
from pybtex.database.input import bibtex
from pybtex.database import BibliographyData, Entry
from unicodedata import normalize

pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 100)

# %% [markdown]
# ##### Criação de funções

# %%
######################## LISTAGEM DE ARQUIVOS
def arquivos(path, fendwith = ''):
    if fendwith not in '':
        caminhos = {nome : os.path.join(path, nome) for nome in os.listdir(path) if nome.endswith(fendwith)}
    else:
        caminhos = {nome : os.path.join(path, nome) for nome in os.listdir(path)}
    return caminhos

######################## LISTAGEM DE AUTORES
def author_names(author):
    try:
        return author.persons['author'][0:]
    except:
        return {'author': [(u'none, none')]}

######################## CONCATENA AUTORES
def join_names(person):
    try:
        return person.last_names[0] + ', ' + person.first_names[0]
    except:
        return []

######################## OUTPUT POR TIPO DE EXTENSAO(JSON, YAML E CSV)
def type_output_file(o_data, f_type, filename, path):

    path_complete = path + filename + '.' + f_type

    if f_type == 'yaml':
        with open(path_complete, 'w') as nfile:
            yaml.dump(o_data.to_dict(orient='records'), nfile)

    if f_type == 'json':
        with open(path_complete, 'w') as nfile:
            result = o_data.to_json(orient="records")
            parsed = json.loads(result)
            json.dump(parsed, nfile, indent=4)  

    if f_type == 'csv':
        o_data.to_csv(path_complete, sep='§')

######################## CARGA DO ARQUIVO DE CONFIGURACAO
def load_config(n_file):
    with open(n_file, 'r') as config_file:
        return yaml.load(config_file, Loader=yaml.SafeLoader)

# %% [markdown]
# ## Inicia importanção dos arquivos

# %% [markdown]
# ### BIBTEX
# - ref bibtex doc: http://paginapessoal.utfpr.edu.br/jamhour/publicacoes/arquivos/00_Compilado_JabRef_dez2015.pdf

# %%
source_path = "C:\\Users\\Maiyuri\\Documents\\trabalho python\\BibtexDataQuality\\source\\"


lst_files = arquivos(source_path, '.bib')
parser = bibtex.Parser()
# file = parser.parse_file(lst_files['ACM.bib'])
dict_file_fields = {}
list_file_fields = []

#verifica a estrutura de campos para cada tipo de publicação
#cria um dicionario usando como chave a fonte e o tipo de publicação
for f in lst_files:
    parser = bibtex.Parser()
    file = parser.parse_file(lst_files[f])
    f_name = f.replace('.bib','')
    for i in file.entries.values():
        
        for a in sorted(i.fields.keys()):
           
            if a not in list_file_fields:
                list_file_fields.append(a)
list_file_fields.remove('ISSN')

# %% [markdown]
# ##### importanção e tratamento

# %%
lst_files = arquivos(source_path)
parser = bibtex.Parser()
# file = parser.parse_file(lst_files['IEEE.bib'])
dict_bib = {}

for f in lst_files:
    
    ############# IEEE
    if 'IEEE' in f :
        parser = bibtex.Parser()
        file = parser.parse_file(lst_files[f])

        for i in file.entries.values():
            key = i.key
            dict_bib[key] = {i.fields.get('fields', fields) : i.fields.get(fields, '')\
                            for fields in list_file_fields}
            
            dict_bib[key]['type_publication'] = i.type
            dict_bib[key]['author'] = [join_names(person) for person in i.persons.get('author', '')]

            dict_bib[key].update({'keywords' : dict_bib[key]['keywords'].split(';')})
    
    ############## ACM
    if 'acm' in f:
        parser = bibtex.Parser()
        file = parser.parse_file(lst_files[f])

        for i in file.entries.values():
            key = i.key
            dict_bib[key] = {i.fields.get('fields', fields) : i.fields.get(fields, '')\
                            for fields in list_file_fields}
            
            dict_bib[key]['type_publication'] = i.type
            dict_bib[key]['author'] = [join_names(person) for person in i.persons.get('author', '')]

            dict_bib[key].update({'keywords' : dict_bib[key].get('keywords', '').split(';')})

            if i.type == 'inbook':
                dict_bib[key].update({'doi' : dict_bib[key].get('url', '').replace('https://doi.org/', '')})

    ############## Science Direct
    if 'ScienceDirect' in f:
        parser = bibtex.Parser()
        file = parser.parse_file(lst_files[f])

        for i in file.entries.values():
            key = i.key
            dict_bib[key] = {i.fields.get('fields', fields) : i.fields.get(fields, '')\
                        for fields in list_file_fields}
            
            dict_bib[key]['type_publication'] = i.type
            dict_bib[key]['author'] = [join_names(person) for person in i.persons.get('author', '')]
            dict_bib[key].update({'keywords' : dict_bib[key]['keywords'].split(';')})
            
            dict_bib[key].update({'doi' : i.fields['doi'].replace('https://doi.org/', '')})

df_bib = pd.DataFrame(data=dict_bib.values())

# %%
print(dict_bib['10.1145/3502771.3502781'])
# Out:
# {'abstract': 'Cyber-physical systems (CPS) have been developed in many industrial sectors and application domains in which the quality requirements of data acquired are a common factor. Data quality in CPS can deteriorate because of several factors such as sensor faults and failures due to operating in harsh and uncertain environments. How can software engineering and artificial intelligence (AI) help manage and tame data quality issues in CPS? This is the question we aimed to investigate in the SEA4DQ workshop. Emerging trends in software engineering need to take data quality management seriously as CPS are increasingly datacentric in their approach to acquiring and processing data along the edge-fog-cloud continuum. This workshop provided researchers and practitioners a forum for exchanging ideas, experiences, understanding of the problems, visions for the future, and promising solutions to the problems in data quality in CPS. Examples of topics include software/hardware architectures and frameworks for data quality management in CPS; software engineering and AI to detect anomalies in CPS data or to repair erroneous CPS data. SEA4DQ 2021, which took place on August 24th, 2021 was a satellite event of the ACM Joint European Software Engineering Conference and Symposium on the Foundations of Software Engineering (ESEC / FSE) 2021. The workshop attracted 35 international participants and was exciting with a great keynote, six excellent presentations, and concluded on a high note with a panel discussion. SEA4DQ was motivated by the common research interests from the EU projects for Zero-Defects Manufacturing such as InterQ and Dat4.Zero.', 'address': 'New York, NY, USA', 'doi': '10.1145/3502771.3502781', 'issn': '0163-5948', 'issue_date': 'January 2022', 'journal': 'SIGSOFT Softw. Eng. Notes', 'month': 'jan', 'number': '1', 'numpages': '4', 'pages': '26–29', 'publisher': 'Association for Computing Machinery', 'title': "Software Engineering and AI for Data Quality in Cyber- Physical Systems - SEA4DQ'21 Workshop Report", 'url': 'https://doi.org/10.1145/3502771.3502781', 'volume': '47', 'year': '2022', 'booktitle': '', 'isbn': '', 'keywords': [''], 'location': '', 'series': '', 'articleno': '', 'note': '', 'edition': '', 'type_publication': 'article', 'author': ['Nguyen, Phu', 'Sen, Sagar', 'Jourdan, Nicolas', 'Cassoli, Beatriz', 'Myrseth, Per', 'Armendia, Mikel', 'Myklebust, Odd']}

# %% [markdown]
# #### Output BIBTEX

# %%
config = load_config('config.yaml')        

output_path = config['output_path'][0]
f_name = config['file_name'][0]
file_ext = config['output_ext'][0]

type_output_file(df_bib, file_ext, f_name, output_path)

# %% [markdown]
# ### CSV SCIMAGO | JSR

# %% [markdown]
# ##### Criando Funções

# %%
source_excel = "C:\\Users\\Maiyuri\\Documents\\trabalho python\\BibtexDataQuality\\source\\excel"
lst_excel = arquivos(source_excel)

######################## REMOVE CARACTERES ESPECIAIS
def rmscaract(text):
    result = [re.sub(r"[^a-zA-Z0-9]","", normalize('NFKD', words).encode('ASCII','ignore').decode('ASCII').lower()) for words in text.fillna('')]
    return result

######################## CRIA UM HASH A PARTIR DE UMA STRING
def stringhash(instr):
    hashnum = [hashlib.md5(ikeys.encode()).hexdigest() for ikeys in instr]
    return hashnum

######################## CRIA HASH JÁ COM STRING TRATADA
def hashkey(strkeys):
    stringadjs = rmscaract(strkeys)
    hashresult = [hashlib.md5(ikeys.encode()).hexdigest() for ikeys in stringadjs]
    return hashresult

######################## FUNÇÃO PARA FILTRAGEM
def filter_exp(df):
    a = config['filter_field'][0] + config['search_operator'][0] + "'" + config['search_value'][0] + "'"
    return df.query(a)

# %% [markdown]
# ##### importanção e tratamento

# %% [markdown]
# ###### JCS

# %%
df_jcs = pd.read_csv(lst_excel['jcs_2020.csv'], delimiter=';').drop_duplicates(subset='Full Journal Title')
cols = ['Rank', 'Full Journal Title','Total Cites', 'Journal Impact Factor', 'Eigenfactor Score']

df_jcs = df_jcs[cols]
df_jcs['hashid'] =  hashkey(df_jcs['Full Journal Title'])
df_jcs = df_jcs.rename(columns={'Journal Impact Factor' : 'jcr_value'})

df_jcs['hashid'].count()
# dfjcs
# Out:
# 12312

# %% [markdown]
# ###### SCIMAGO

# %%
df_scimago = pd.read_csv(lst_excel['scimagojr 2020.csv'], delimiter=';').drop_duplicates()

df_scimago['hashid'] =  hashkey(df_scimago['Title'])
df_scimago['issnkey'] =  df_scimago.Issn.str.slice(stop=8)
df_scimago = df_scimago.rename(columns={'SJR' : 'scimago_value'})

df_scimago['hashid'].count()
# dfscimago
# Out:
# C:\Users\Maiyuri\AppData\Local\Temp\ipykernel_5928\4210968985.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_scimago = pd.read_csv(lst_excel['scimagojr 2020.csv'], delimiter=';').drop_duplicates()
# 32952

# %% [markdown]
# ###### JUNÇÃO JCS | SCIMAGO

# %%
dfjournalrank = df_scimago.merge(df_jcs, left_on=['hashid'], right_on=['hashid'],how='outer')

dfjournalrank['Title'] = (dfjournalrank.Title.combine_first(dfjournalrank['Full Journal Title'])).str.lower()
print(dfjournalrank[['Full Journal Title','Title']].count())

dfjournalrank = dfjournalrank.drop(columns=['Rank_x', 'Rank_y', 'Full Journal Title'])
# dfjournalrank
# Out:
# Full Journal Title    12325
# Title                 34727
# dtype: int64

# %% [markdown]
# ## JOIN BIBTEX | CSV SCIMAGO | CSV JCS

# %%
df_bib = pd.DataFrame(data=dict_bib.values())
df_bib = df_bib.replace(r'^\s*$', nan, regex=True)

df_bib['issnkey'] = rmscaract(df_bib['issn'])
df_bib['title'] = rmscaract(df_bib['title'])
df_bib['hashid'] = hashkey(df_bib['title'])

# %%
cols = ['issnkey', 'isbn', 'journal', 'publisher', 'title', 'booktitle', 'doi', 'author', 'keywords', 'abstract', 'year', 'type_publication', 'jcr_value', 'scimago_value']

df_join_bibtex_csv = df_bib.merge(dfjournalrank, left_on = 'issnkey', right_on = 'issnkey', how = 'left' )
df_join_bibtex_csv = df_join_bibtex_csv[cols]

# %%
def filter_exp(df):
    a = config['filter_field'][0] + config['search_operator'][0] + "'" + config['search_value'][0] + "'"
    return df.query(a)

# %%
config = load_config('config.yaml')        

output_path = config['output_path'][0]
f_name = config['file_name'][0]
file_ext = config['output_ext'][0]

df_filter = filter_exp(df_join_bibtex_csv)

type_output_file(df_filter, file_ext, f_name, output_path)

# %% [markdown]
# ## API

# %%
def buscar_dados(n_api):
    if 'IEEE' in n_api:
        accesskey_IEEE = 'efugu53u622asc77hu7h6hbq'
        request = requests.get("https://ieeexploreapi.ieee.org/api/v1/search/articles?parameter&apikey=" + accesskey_IEEE)
        dict_values = json.loads(request.content)['articles']
    
    if 'ScienceDirect' in n_api:
        accesskey_SD = 'ef8a7260c27897693d0fd7394a559726'
        request = requests.get("http://api.elsevier.com/content/search/scopus?query=heart&apiKey=" + accesskey_SD)
        dict_values = dict(json.loads(request.content)['search-results'])['entry']
        
    return pd.DataFrame(dict_values)

# %%
df_ieee = buscar_dados('IEEE')
df_api_sd = buscar_dados('ScienceDirect')

cols = ['doi', 'title', 'publisher', 'isbn', 'issn', 'abstract', 'html_url', 'publication_title',  'publication_year']

df_ieee = df_ieee[cols]
df_api_sd = df_api_sd

# %%
# dict_api_sd = {}

# for i in dict_api_sd['articles']:
#     print(i)
#     key = i.key
#     dict_api[key] = {i.fields.get('fields', fields) : i.fields.get(fields, '')\
#                     for fields in list_file_fields}
    
#     dict_bib[key]['type_publication'] = i.type
#     dict_bib[key]['author'] = [join_names(person) for person in i.persons.get('author', '')]

#     dict_bib[key].update({'keywords' : dict_bib[key]['keywords'].split(';')})

# %% [markdown]
# ## Buscando string dentro da api

# %%
config = load_config('config.yaml')        

string_search = config['content_type'][0]

# %%
string_search
# Out:
# 'Courses'

# %%
accesskey_IEEE = 'efugu53u622asc77hu7h6hbq'
request = requests.get("https://ieeexploreapi.ieee.org/api/v1/search/articles?content_type=" + string_search + "&apikey=efugu53u622asc77hu7h6hbq")
dict_values = json.loads(request.content)['articles']

# %%
dict_values
# Out:
# [{'title': 'Engaging Consumers in the Smart Grid Marketplace',
#   'publisher': 'IEEE',
#   'isbn': '978-1-5386-8565-5',
#   'rank': 1,
#   'authors': {'authors': [{'full_name': 'John D. McDonald',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'Covers the new power industry reality, including consumers, third parties, and future markets.',
#   'article_number': 'EDP547',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP547',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP547',
#   'publication_title': 'Engaging Consumers in the Smart Grid Marketplace',
#   'publication_year': 2019,
#   'publication_date': '4/1/2019',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Smart grids',
#      'Power engineering and energy',
#      'Power grids',
#      'Power systems',
#      'Computer security',
#      'Information and communication technology',
#      'Data privacy',
#      'Energy efficiency',
#      'Protocols',
#      'Intelligent systems',
#      'Power distribution',
#      'Power system reliability']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-5386-8565-5'}]}},
#  {'title': 'Enterprise Blockchain for Grid Modernization',
#   'publisher': 'IEEE',
#   'isbn': '978-1-5386-8573-0',
#   'rank': 2,
#   'authors': {'authors': [{'full_name': 'Dr. Claudio Lima',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'Blockchain for Grid Modernization and Energy provides an overview of the benefits of Blockchain for grid management, an explanation on how Blockchain for energy works, some key drivers of adoption for energy and the Open Blockchain Energy (OBE) framework for Blockchain adoption to manage modern energy grid networks more efficiently.  Finally we highlight the transactive energy model where grids are managed at a more granular level enabling higher efficiencies and better localized utilization of energy networks.',
#   'article_number': 'EDP551',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP551',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP551',
#   'publication_title': 'Enterprise Blockchain for Grid Modernization',
#   'publication_year': 2019,
#   'publication_date': '5/22/2019',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Computers and information processing',
#      'Blockchain',
#      'Cryptocurrency',
#      'Cloud computing']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-5386-8573-0'}]}},
#  {'title': 'SRAM Design - Write Path',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4244-6134-9',
#   'rank': 3,
#   'authors': {'authors': [{'full_name': 'Doug Sheppard', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'Course content reaffirmed: 06/2015--The overall data path of a memory can be divided into two paths - the read path and the write path. This tutorial focuses on the write path of an SRAM. The write path has some unique requirements that the read path does not have, although there are some similarities as well. This design will include: the internal decoding for a write, the data in buffer and key control circuits along with their timing relationships. The overall integration of the write and read path will be designed thereby making up the complete data path into and out of the memory cell. A complete set of plots are provided along with a SPICE netlist that is extracted from the layout.',
#   'article_number': 'EDP117',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP117',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP117',
#   'publication_title': 'SRAM Design - Write Path',
#   'publication_year': 2009,
#   'publication_date': '11/23/2009',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'SRAM chips',
#      'Memory management',
#      'Circuits and systems',
#      'Design automation',
#      'Integrated circuits',
#      'Layout',
#      'Circuit synthesis',
#      'SPICE',
#      'Path planning',
#      'Random access memory',
#      'Decoding',
#      'Data models',
#      'Data processing']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4244-6134-9'}]}},
#  {'title': 'Principles and Applications of RFID',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4244-6138-7',
#   'rank': 4,
#   'authors': {'authors': [{'full_name': 'You Chung Chung',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This tutorial will begin by reviewing auto ID comparison with bar Code and the origin of RFID. RFID System, elements, Tag Types, and Operation will also be examined. The tutorial  will also present RFID characteristics and will show how RFID systems are classified. A brief overview of Frequency Band (ISO) & Communication Methods will also be presented. A review of applications will also be discussed.',
#   'article_number': 'EDP121',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP121',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP121',
#   'publication_title': 'Principles and Applications of RFID',
#   'publication_year': 2009,
#   'publication_date': '12/29/2009',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'Radiofrequency identification',
#      'Bar codes',
#      'Smart devices',
#      'RFID tags',
#      'Product codes',
#      'Inventory management',
#      'Active RFID tags',
#      'Passive RFID tags']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4244-6138-7'}]}},
#  {'title': '(CSDA) Software Quality',
#   'publisher': 'IEEE',
#   'isbn': '1-4673-3153-8',
#   'rank': 5,
#   'authors': {'authors': [{'full_name': 'Massood Towhidnejad',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This tutorial is part of a series of eLearning courses designed to help you prepare for the examination to become a Certified Software Development Associate (CSDA) or to learn more about specific software engineering topics. Courses in this series address one or more of the fifteen Knowledge Areas that comprise the Software Engineering Body of Knowledge - or SWEBOK, upon which the Certification Exam is based. This course is intended to assess your understanding of software requirements through inline quizzes and feedback. The CSDA credential is intended for graduating software engineers and entry-level software professionals and serves to bridge the gap between your educational experience and real-world work requirements. This knowledge area deals with software quality considerations which transcend the life cycle processes. Software quality is a ubiquitous concern in software engineering, and so it is also considered in many of the other SWEBOK Knowledge Areas. ',
#   'article_number': 'EDP300',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP300',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP300',
#   'publication_title': '(CSDA) Software Quality',
#   'publication_year': 2012,
#   'publication_date': '7/26/2012',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'Software engineering',
#      'Knowledge engineering',
#      'Electronic learning',
#      'Certification',
#      'Software development management',
#      'Software quality',
#      'Software performance']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '1-4673-3153-8'}]}},
#  {'title': 'Other Issues in WPT',
#   'publisher': 'IEEE',
#   'isbn': '978-1-5090-0504-8',
#   'rank': 6,
#   'authors': {'authors': [{'full_name': 'Chris Mi', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This course will review other aspects of wireless chargers, such as safety issues, switching frequency band requirement, SAE WPT J2954 standard, object detection methods, communication methods between transmitter and receiver, some testing results of foreign object inserted between the transmitter and receiver are shown. Topics covered include: Human, animal and environment safety; Object detection; SAE J2954 standard for WPT; Wireless communication between the transmitter and receiver; Inductive coupling vs. capacitive coupling; In-motion charging vs. stationary charging and Other applications of WPT: medical, appliance, consumer electronics.',
#   'article_number': 'EDP439',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP439',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP439',
#   'publication_title': 'Other Issues in WPT',
#   'publication_year': 2015,
#   'publication_date': '7/15/2015',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Transmitters',
#      'Receivers',
#      'Wireless communication',
#      'Safety',
#      'Object detection',
#      'Couplings',
#      'Switching systems',
#      'Environmental factors',
#      'Human factors',
#      'Animals',
#      'Wireless power transfer']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-5090-0504-8'}]}},
#  {'title': 'IEEE/IAPP Data Privacy Engineering Collection',
#   'publisher': 'IAPP',
#   'rank': 7,
#   'authors': {'authors': [{'full_name': 'IEEE/IAPP', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'IEEE has partnered with International Association of Privacy Professionals (IAPP) to bundle IEEE content with the IAPP Certified Information Privacy Technologist (CIPT) Training and Certification. A leading training certification course in the field of data privacy, the CIPT credential is ANSI accredited, and demonstrates that a technologist has the practical knowledge to apply privacy and data protection practices in the development, engineering, deployment or auditing of products and services. ',
#   'article_number': 'EDP618',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP618',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP618',
#   'publication_title': 'IEEE/IAPP Data Privacy Engineering Collection',
#   'publication_year': 2021,
#   'publication_date': '5/26/2021',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN'}]}},
#  {'title': 'Dual Port Sram - Data In Buffer',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4673-0621-8',
#   'rank': 8,
#   'authors': {'authors': [{'full_name': 'Doug Sheppard', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'Course content reaffirmed: 06/2015--There are several important timings that must be considered when designing the Data In Buffer that go beyond amplifying the input signal to drive the data to be written into the bit cell. The control timing must be such that the hold time for data in from the customer can be zero and not cause a change on the pin to propagate all the way to the bit cell and disturb what was just written. This tutorial makes a deeper evaluation of the timing paths that must be considered between clock and data in.',
#   'article_number': 'EDP264',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP264',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP264',
#   'publication_title': 'Dual Port Sram - Data In Buffer',
#   'publication_year': 2011,
#   'publication_date': '12/15/2011',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['SRAM chips',
#      'Data models',
#      'Data processing',
#      'SPICE',
#      'Simulation',
#      'Buffer storage',
#      'Buffer overflows',
#      'Data storage',
#      'Decoding',
#      'Random access memory']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4673-0621-8'}]}},
#  {'title': 'Introduction to Developing Embedded Systems',
#   'publisher': 'IEEE',
#   'isbn': '0-7803-9648-0',
#   'rank': 9,
#   'authors': {'authors': [{'full_name': 'Kim Fowler', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This tutorial will introduce important issues in preparing, designing, and developing a product including: Systems Engineering; Process, design, and development; Architecture; Hardware, Software, Tradeoffs; Interface choices; Reliability versus fault tolerance; Review and Testing - Debugging, inspections, integration, validation, verification; Documentation; The Human Interface - User-centered design, elements of successful interfaces; Packaging - Its influence, environmental issues, wiring and assembly issues; Power - Types of converters and distribution; Cooling - Mechanisms, types of heat transfer, and tradeoffs; Problems - types of problems: failure, remedies, integrity.',
#   'article_number': 'EDP009',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP009',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP009',
#   'publication_title': 'Introduction to Developing Embedded Systems',
#   'publication_year': 2005,
#   'publication_date': '1/15/2005',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Embedded systems',
#      'Tutorials',
#      'Systems engineering and theory',
#      'Computer architecture',
#      'Reliability engineering',
#      'Software reliability',
#      'Fault tolerant systems',
#      'Human factors',
#      'Encoding',
#      'Power distribution',
#      'Converters',
#      'Power distribution',
#      'Heat transfer',
#      'Failure analysis',
#      'Real-time systems',
#      'Application specific integrated circuits',
#      'User centered design',
#      'Field programmable gate arrays']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '0-7803-9648-0'}]}},
#  {'title': 'Optoelectronic Devices for Fiber Optics',
#   'publisher': 'IEEE',
#   'isbn': '0-7803-9652-9',
#   'rank': 10,
#   'authors': {'authors': [{'full_name': 'Joe C. Campbell',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This course provides an introductory, tutorial-type overview of key optoelectronic devices for optical communication systems, specifically, semiconductor lasers, photodetectors, optical modulators, and some WDM components. The course covers a broad range of devices with an emphasis on fundamental device physics and operating principles. Important performance parameters including design trade-offs will also be discussed. The laser section will discuss applications and the types of lasers that are utilized for specific systems. Topics include multiple quantum well lasers, distributed feedback lasers, wavelength tunable lasers and vertical cavity surface emitting lasers. Photodetector topics will cover wide-bandwidth PINs and avalanche photodiodes as well as receivers with optical preamplification. State-of-the-art integrated receiver circuits will also be discussed. In the modulator section Mach-Zehnder interferometers, and quantum-confined-Stark-effect devices will be covered. There will be a brief description of recent developments in optical switching using MEMs technology.',
#   'article_number': 'EDP013',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP013',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP013',
#   'publication_title': 'Optoelectronic Devices for Fiber Optics',
#   'publication_year': 2005,
#   'publication_date': '3/1/2005',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Optoelectronic devices',
#      'Optical fiber networks',
#      'Distributed feedback devices',
#      'Vertical cavity surface emitting lasers',
#      'Laser feedback',
#      'Optical feedback',
#      'Wavelength division multiplexing',
#      'Lasers',
#      'Mach-Zehnder interferometers',
#      'PIN photodiodes',
#      'Electrooptic devices',
#      'Optical switches']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '0-7803-9652-9'}]}},
#  {'title': 'Machine Learning in the Age of Enterprise Big Data',
#   'publisher': 'IEEE',
#   'isbn': '978-1-5386-8605-8',
#   'rank': 11,
#   'authors': {'authors': [{'full_name': 'Grant Scott', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This course focuses on the foundations of big data, machine learning, artificial intelligence, and computational intelligence. It looks at enhancing business intelligence with machine learning, examines the fundamental types of machine learning that drive business insights, and reviews advanced computational intelligence for business processes.\n',
#   'article_number': 'EDP590',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP590',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP590',
#   'publication_title': 'Machine Learning in the Age of Enterprise Big Data',
#   'publication_year': 2020,
#   'publication_date': '11/30/2020',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-5386-8605-8'}]}},
#  {'title': 'Understanding SMPTE ST 2110: Background and System Overview',
#   'publisher': 'SMPTE',
#   'isbn': '978-1-5386-0031-3',
#   'rank': 12,
#   'authors': {'authors': [{'full_name': 'Thomas Bause Mason',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': "This course is intended for engineers and technologists who need to understand the detail in SMPTE's ST 2110 suite of standards. It assumes a basic understanding of IP and associated terminology. The focus of this course is Background and System Overview. We begin by describing why the move to IP is important for the broadcast industry. Next we explain how media is transported over IP networks. We then discuss how the SMPTE ST 2110 standards suite was created. Finally we will specify the different areas of application for SMPTE ST 2110 and SMPTE ST 2022.",
#   'article_number': 'EDP514',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP514',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP514',
#   'publication_title': 'Understanding SMPTE ST 2110: Background and System Overview',
#   'publication_year': 2018,
#   'publication_date': '7/6/2018',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['SMPTE Standards',
#      'IP networks',
#      'Broadcasting',
#      'Media',
#      'Streaming media',
#      'Transport protocols',
#      'Communication systems']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-5386-0031-3'}]}},
#  {'title': 'SRAM Design - Control Circuitry',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4244-6177-6',
#   'rank': 13,
#   'authors': {'authors': [{'full_name': 'Doug Sheppard', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'Course content reaffirmed: 06/2015--The previous tutorials in this series focused on the design of individual circuits. Now we begin putting it all together. This tutorial will focus on the interaction between the circuits and their key timing relationships by comparing the individual timing paths. The control circuit will be designed to create: global signals for activating the word lines, passing and latching the address, set-up time, hold time, enabling and disabling pre-charge, read select timing and write select timing. Adhering to a fanout of 4 will greatly aid in quickly evaluating each timing path without initially needing to run SPICE simulations.',
#   'article_number': 'EDP160',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP160',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP160',
#   'publication_title': 'SRAM Design - Control Circuitry',
#   'publication_year': 2010,
#   'publication_date': '4/8/2010',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'SRAM chips',
#      'Memory management',
#      'Circuits and systems',
#      'Design automation',
#      'Integrated circuits',
#      'Layout',
#      'Circuit synthesis',
#      'SPICE',
#      'Path planning',
#      'Random access memory',
#      'Decoding',
#      'Data models',
#      'Data processing',
#      'Sensors',
#      'Signal processing',
#      'CMOS integrated circuits']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4244-6177-6'}]}},
#  {'title': '(CSDA) Software Engineering Process',
#   'publisher': 'IEEE',
#   'isbn': '1-4673-3152-X',
#   'rank': 14,
#   'authors': {'authors': [{'full_name': 'Massood Towhidnejad',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This tutorial is part of a series of eLearning courses designed to help you prepare for the examination to become a Certified Software Development Associate (CSDA) or to learn more about specific software engineering topics. Courses in this series address one or more of the fifteen Knowledge Areas that comprise the Software Engineering Body of Knowledge - or SWEBOK, upon which the Certification Exam is based. This course is intended to assess your understanding of software requirements through inline quizzes and feedback. The CSDA credential is intended for graduating software engineers and entry-level software professionals and serves to bridge the gap between your educational experience and real-world work requirements. Software engineering process can be examined on two levels. The first level encompasses the technical and managerial activities within the software life cycle processes that are performed during software acquisition, development, maintenance and retirement. The second is the meta-level, which is concerned with the definition, implementation, assessment, measurement, management, change and improvement of the software life cycle processes themselves. The first level is covered by other CSDA Knowledge Area courses. This course concentrates on the second level.',
#   'article_number': 'EDP299',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP299',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP299',
#   'publication_title': '(CSDA) Software Engineering Process',
#   'publication_year': 2012,
#   'publication_date': '7/30/2012',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'Software engineering',
#      'Knowledge engineering',
#      'Electronic learning',
#      'Certification',
#      'Software development management',
#      'Product life cycle management']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '1-4673-3152-X'}]}},
#  {'title': 'Software and Systems Engineering Standards: Software Testing Driven by Standards and Models',
#   'publisher': 'IEEE',
#   'isbn': '978-1-7281-7797-7',
#   'rank': 15,
#   'authors': {'authors': [{'full_name': 'Jon Duncan Hager',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This course offers an overview of the IEEE 29119 series of standards for software testing and teaches its applicability during the complete software lifecycle with and emphasis on Aerospace and Defense specifically. Topics include identifying the role, benefits, and need for software test modeling over the complete software lifecycle; how systems, software, modeling, V&V, and test engineering standards work with each other, the applicability of ISO/IEEE 29119 series for Aerospace and Defense usage. Note: A portion of this course is expanded into the course, Software and Systems Engineering Standards: Using ISO/IEC/IEEE 29119 for Software Testing, which provides an overview of the five supporting parts of the IEEE 29119 series of standards from proposal to retirement.',
#   'article_number': 'EDP657',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP657',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP657',
#   'publication_title': 'Software and Systems Engineering Standards: Software Testing Driven by Standards and Models',
#   'publication_year': 2021,
#   'publication_date': '2/14/2022',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-7281-7797-7'}]}},
#  {'title': '(CSDP) Software  Quality',
#   'publisher': 'IEEE',
#   'isbn': '978-1-61284-518-0',
#   'rank': 16,
#   'authors': {'authors': [{'full_name': 'David Waxman', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This tutorial is part of a series of eLearning courses designed to help you prepare for the examination to become a Certified Software Development Professional (CSDP) or to learn more about specific software engineering topics. Courses in this series address one or more of the fifteen Knowledge Areas that comprise the Software Engineering Body of Knowledge - or SWEBOK, upon which the Certification Exam is based. Within each course module, there is a list of textbooks, courses and relevant reference materials to assist you in preparing for the Certification Exam. Software Quality deals with considerations which transcend the life cycle process. Software quality is a ubiquitous concern in software engineering, and do it is also considered in many of the KAs. In particular, this KA covers static techniques - those which do not require the execution of the software being evaluated, while dynamic techniques are covered in the Software Testing KA. This course is intended to assess your understanding of software quality through inline quizzes and feedback. Specific topics addressed in this course are:  fundamentals of software quality, software quality management processes, and software quality practical considerations.',
#   'article_number': 'EDP227',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP227',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP227',
#   'publication_title': '(CSDP) Software  Quality',
#   'publication_year': 2011,
#   'publication_date': '6/30/2011',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'Software engineering',
#      'Knowledge engineering',
#      'Electronic learning',
#      'Certification',
#      'Software development management',
#      'Software quality',
#      'Software testing',
#      'Software reliability',
#      'Software maintenance',
#      'Software quality']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-61284-518-0'}]}},
#  {'title': 'Fiber Optic Cable  -  Cable Specifications, Preparation, and Specialty Cables',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4244-6152-3',
#   'rank': 17,
#   'authors': {'authors': [{'full_name': 'Larry Johnson', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'In this tutorial we will begin with a review of cable specifications which includes a discussion of physical size issues and environmental and grounding issues. You will also learn about the preparation of loose and tight buffered cables. This is followed by a review of OPGW cables and the unique disciplines, tools, processes and attachment hardware for OPGW preparation. Finally, ADSS cable will be discussed including applications and specialized hardware for ADSS installations. After completing this tutorial you should have an understanding of:  Cable specifications; Loose buffered cable preparation; Tight buffered cable preparation; OPGW cables; OPGW preparation; and ADSS cables.',
#   'article_number': 'EDP0135',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP0135',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP0135',
#   'publication_title': 'Fiber Optic Cable  -  Cable Specifications, Preparation, and Specialty Cables',
#   'publication_year': 2009,
#   'publication_date': '12/14/2009',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'Optical fibers',
#      'Grounding',
#      'Hardware',
#      'Power cables',
#      'Communication cables',
#      'Wiring',
#      'Dielectrics',
#      'Underground power cables',
#      'Power transmission lines',
#      'Power cable insulation']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4244-6152-3'}]}},
#  {'title': 'Cloud Security and Data Protection',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4799-8514-2',
#   'rank': 18,
#   'authors': {'authors': [{'full_name': 'Cloud Strategy Partners, LLC',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'Security is a complex domain and involves multiple aspects of the infrastructure, systems and applications operation as well as user access management. In this tutorial, we will begin with a review of some basics and next will go with cloud specific security aspects. In the basics we will cover the meanings of Security, and Trust, which are different. We will also look at a Security Services Lifecycle Management (SSLM) model. Finally, we will turn to specifics about Security in Cloud Computing. Note we will apply these via a brief analysis of the AWS and Microsoft Azure security.',
#   'article_number': 'EDP406',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP406',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP406',
#   'publication_title': 'Cloud Security and Data Protection',
#   'publication_year': 2014,
#   'publication_date': '1/15/2015',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'Cloud computing',
#      'Data storage systems',
#      'Storage management',
#      'Computer network management',
#      'Computer architecture',
#      'Software architecture',
#      'Information retrieval',
#      'Metasearch',
#      'Application programming interfaces',
#      'Software as a Service',
#      'Queueing analysis',
#      'Computer security']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4799-8514-2'}]}},
#  {'title': 'Introduction to Statistical Variation and Techniques for Design Optimization',
#   'publisher': 'IEEE',
#   'isbn': '0-7803-9672-3',
#   'rank': 19,
#   'authors': {'authors': [{'full_name': 'Norman Rohrer', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': "Variability is a reality in nanometer semiconductor processes. This course will cover the sources of systematic and random variations of transistors and their surrounding interconnects. Included in the variability discussion will be within-chip variability, across-wafer variability, across-device variability, and device mismatch. The resulting impact upon an individual circuit's functionality and timing will be explored. Analytical approaches will be shown for examining the variability's impact upon leakage power, dynamic power, and circuit functionality of static and dynamic circuits, SRAM arrays and PLLs. Techniques will include Monte-Carlo analysis, vector analysis, and statistical timing analysis.",
#   'article_number': 'EDP052',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP052',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP052',
#   'publication_title': 'Introduction to Statistical Variation and Techniques for Design Optimization',
#   'publication_year': 2007,
#   'publication_date': '2/6/2007',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Transistors',
#      'Systematics',
#      'Integrated circuit interconnections',
#      'Random access memory',
#      'Phased locked loops',
#      'Monte Carlo methods',
#      'Negative bias temperature instability']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '0-7803-9672-3'}]}},
#  {'title': 'Engineering Ethics: Power Engineering',
#   'publisher': 'IEEE',
#   'isbn': '978-1-61284-509-8',
#   'rank': 20,
#   'authors': {'authors': [{'full_name': 'Steve Starrett', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'Engineers are trained to think analytically and base their technical decisions on relevant facts and research. Nonetheless, engineers will encounter many situations involving ethical questions during their careers. In order to improve their ability to make ethical decisions engineers require additional tools and training. These include an understanding of the relevant codes of ethics and learning to recognize ethical challenges and solutions through a case study approach. In this tutorial the author discusses the IEEE  Code of Ethics that engineers can use as a reference when they confront ethical questions in professional situations. The author also provides a guided review of  ethical decision-making using a case study in power engineering. Several suggestions and additional references for improving ethical decision-making are offered.',
#   'article_number': 'EDP231',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP231',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP231',
#   'publication_title': 'Engineering Ethics: Power Engineering',
#   'publication_year': 2011,
#   'publication_date': '7/31/2011',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'Ethics',
#      'Engineering profession',
#      'Power industry',
#      'Power engineering and energy']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-61284-509-8'}]}},
#  {'title': 'Hands On? User Accounts and Access Control Management',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4799-8518-0',
#   'rank': 21,
#   'authors': {'authors': [{'full_name': 'Cloud Strategy Partners, LLC',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'In this tutorial you will learn how to work with AWS Access Management (IAM). You will review how to create users and groups in IAM as well as how to configure Access Policy for groups. You will also learn how to establish identity and access federation in IAM with organizational or 3rd party Identity provider and authentication service.',
#   'article_number': 'EDP410',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP410',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP410',
#   'publication_title': 'Hands On? User Accounts and Access Control Management',
#   'publication_year': 2014,
#   'publication_date': '1/15/2015',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'Cloud computing',
#      'Product design',
#      'Companies',
#      'Data storage systems',
#      'Authentication']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4799-8518-0'}]}},
#  {'title': 'Introduction to Overhead Clearances  to Ground, Buildings and Other Installations',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4244-6136-3',
#   'rank': 22,
#   'authors': {'authors': [{'full_name': 'Allen L. Clapp', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This tutorial begins with a review of the National Electric Safety Code Clearance Rules. This is followed by a discussion of the development of clearance requirements. Clearances above ground, rails and water will also be reviewed as well as the maintenance of clearances. Finally, clearances between crossing lines and parallel lines on different supporting structure and clearances to buildings and other installations will be discussed.',
#   'article_number': 'EDP119',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP119',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP119',
#   'publication_title': 'Introduction to Overhead Clearances  to Ground, Buildings and Other Installations',
#   'publication_year': 2009,
#   'publication_date': '12/21/2009',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['National Electric Code',
#      'Power transmission lines',
#      'Safety',
#      'Maintenance engineering',
#      'Electrical safety',
#      'Power transmission lines',
#      'Power distribution lines']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4244-6136-3'}]}},
#  {'title': 'Charles Kao: "Father of Fiber Optics"',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4244-6140-0',
#   'rank': 23,
#   'authors': {'authors': [{'full_name': 'Larry Johnson', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'Charles Kao, the father of fiber-optic communications, was recently awarded a share of the Nobel prize for his work in physics. On October 16th, 2001, Larry Johnson had the opportunity to film an interview with Dr. Kao at the Stanford Park Hotel in Palo Alto, California. ',
#   'article_number': 'EDP123',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP123',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP123',
#   'publication_title': 'Charles Kao: "Father of Fiber Optics"',
#   'publication_year': 2009,
#   'publication_date': '12/21/2009',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Optical fiber communication',
#      'Physics',
#      'Interviews',
#      'Awards']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4244-6140-0'}]}},
#  {'title': '(CSDA) Mathematical Foundations',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4673-0637-9',
#   'rank': 24,
#   'authors': {'authors': [{'full_name': 'Peter B. Henderson',
#      'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'This tutorial is part of a series of eLearning courses designed to help you prepare for the examination to become a Certified Software Development Associate (CSDA) or to learn more about specific software engineering topics. Courses in this series address one or more of the fifteen Knowledge Areas that comprise the Software Engineering Body of Knowledge - or SWEBOK, upon which the Certification Exam is based. This course is intended to assess your understanding of software requirements through inline quizzes and feedback. The CSDA credential is intended for graduating software engineers and entry-level software professionals and serves to bridge the gap between your educational experience and real-world work requirements. The mathematical fundamentals of software engineering provide the mathematical underpinnings for the construction of software products with desired attributes. They provide the mathematical foundations to model and facilitate reasoning about these products and their interrelations, as well as form the basis for a predictable design process.',
#   'article_number': 'EDP302',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP302',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP302',
#   'publication_title': '(CSDA) Mathematical Foundations',
#   'publication_year': 2012,
#   'publication_date': '8/24/2012',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['Tutorials',
#      'Software engineering',
#      'Knowledge engineering',
#      'Electronic learning',
#      'Certification',
#      'Software development management',
#      'Mathematics']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4673-0637-9'}]}},
#  {'title': 'Cellular Wave Computers--Via Million Processing',
#   'publisher': 'IEEE',
#   'isbn': '978-1-4244-2981-3',
#   'rank': 25,
#   'authors': {'authors': [{'full_name': 'Tamas Roska', 'author_order': 1}]},
#   'access_type': 'LOCKED',
#   'content_type': 'Courses',
#   'abstract': 'The cellular wave computer architecture, based on the CNN universal machine principle, has been implemented recently in many different physical forms. The mixed mode CMOS, the emulated digital (cell wise or as aggregated arrays), FPGA, DSP, as well as optical implementations are the main examples. In many cases, the sensory array is integrated as well. This course will begin with an introduction that provides a historical overview. The author then presents mind inspired and brain inspired computing models, the role of spatial address of a processor, and new directions and products in computing the technology scenario. Other topics that will be addressed include: the Cellular Wave Computer; the Cell Processors; the Biology Relevance; the Algorithmic Scenario; and beyond Boolean logic.',
#   'article_number': 'EDP087',
#   'html_url': 'https://ieeexplore.ieee.org/courses/details/EDP087',
#   'abstract_url': 'https://ieeexplore.ieee.org/courses/details/EDP087',
#   'publication_title': 'Cellular Wave Computers--Via Million Processing',
#   'publication_year': 2009,
#   'publication_date': '7/12/2009',
#   'citing_paper_count': 0,
#   'citing_patent_count': 0,
#   'index_terms': {'ieee_terms': {'terms': ['CMOS technology',
#      'Microprocessors',
#      'Optical arrays',
#      'Field programmable gate arrays',
#      'Biomedical optical imaging',
#      'Optical sensors',
#      'Sensors arrays',
#      'Computer architecture',
#      'Boolean functions',
#      'Cellular networks',
#      'Supercomputers']}},
#   'isbn_formats': {'isbns': [{'format': 'Electronic ISBN',
#      'value': '978-1-4244-2981-3'}]}}]

# %% [markdown]
# ## Escrevendo os dados no banco de dados

# %%
#conexao com o banco

from sqlalchemy import create_engine

engine = create_engine('sqlite:///Bd_Publications.db', echo=False)

# %%
engine.execute('''drop table tb_Publications''')

# %%
#criação da tabela
engine.execute('''CREATE TABLE tb_Publications (
        doi varchar(500) null,
        title varchar(500) null,
        publisher varchar(500) null,
        isbn varchar(500) null,
        issn varchar(500) null,
        abstract varchar(500) null,
        html_url varchar(500) null,	
        publication_title varchar(500) null,	
        publication_year int null
    )''')

# %%
#setando a coluna que será o index
df=df_ieee.set_index('doi')

# %%
#inserção tabela
df.to_sql('tb_Publications', con=engine, if_exists='append')
# Out:
# 25

# %%
#leitura da tabela para validar se os dados foram escritos corretamente
query = "SELECT * FROM tb_Publications;"

df_table = pd.read_sql_query(query,engine)

# %%
df_table
# Out:
#                            doi  \
# 0         10.1109/CVPR.2016.90
# 1     10.1109/TAC.1974.1100705
# 2     10.1109/ICNN.1995.488968
# 3      10.1109/TIP.2003.819861
# 4          10.1109/4235.996017
# 5             10.1109/5.726791
# 6    10.1109/CVPR.2015.7298594
# 7    10.1109/CVPR.2009.5206848
# 8      10.1109/TIT.2006.871582
# 9   10.1109/TPAMI.1986.4767851
# 10       10.1109/CVPR.2005.177
# 11           10.1109/34.192463
# 12   10.1109/TSMC.1973.4309314
# 13   10.1109/CVPR.2015.7298965
# 14  10.1162/neco.1997.9.8.1735
# 15             10.1109/5.18626
# 16   10.1109/TSMC.1985.6313399
# 17        10.1109/MCSE.2007.55
# 18        10.1109/CVPR.2016.91
# 19  10.1109/TPAMI.2016.2577031
# 20        10.1109/CVPR.2014.81
# 21       10.1109/CVPR.2017.243
# 22  10.1109/TPAMI.1984.4767596
# 23           10.1109/34.121791
# 24       10.1109/ICCV.2015.169
#
#                                                 title  publisher  \
# 0        Deep Residual Learning for Image Recognition       IEEE
# 1   A new look at the statistical model identifica...       IEEE
# 2                         Particle swarm optimization       IEEE
# 3   Image quality assessment: from error visibilit...       IEEE
# 4   A fast and elitist multiobjective genetic algo...       IEEE
# 5   Gradient-based learning applied to document re...       IEEE
# 6                      Going deeper with convolutions       IEEE
# 7   ImageNet: A large-scale hierarchical image dat...       IEEE
# 8                                  Compressed sensing       IEEE
# 9          A Computational Approach to Edge Detection       IEEE
# 10  Histograms of oriented gradients for human det...       IEEE
# 11  A theory for multiresolution signal decomposit...       IEEE
# 12         Textural Features for Image Classification       IEEE
# 13  Fully convolutional networks for semantic segm...       IEEE
# 14                             Long Short-Term Memory  MIT Press
# 15  A tutorial on hidden Markov models and selecte...       IEEE
# 16  Fuzzy identification of systems and its applic...       IEEE
# 17              Matplotlib: A 2D Graphics Environment       IEEE
# 18  You Only Look Once: Unified, Real-Time Object ...       IEEE
# 19  Faster R-CNN: Towards Real-Time Object Detecti...       IEEE
# 20  Rich Feature Hierarchies for Accurate Object D...       IEEE
# 21           Densely Connected Convolutional Networks       IEEE
# 22  Stochastic Relaxation, Gibbs Distributions, an...       IEEE
# 23            A method for registration of 3-D shapes       IEEE
# 24                                         Fast R-CNN       IEEE
#
#                  isbn       issn  \
# 0   978-1-4673-8852-8  1063-6919
# 1                None  2334-3303
# 2       0-7803-2768-3       None
# 3                None  1941-0042
# 4                None  1941-0026
# 5                None  1558-2256
# 6   978-1-4673-6963-3  1063-6919
# 7   978-1-4244-3991-1  1063-6919
# 8                None  1557-9654
# 9                None  1939-3539
# 10      0-7695-2372-2  1063-6919
# 11               None  1939-3539
# 12               None  2168-2909
# 13  978-1-4673-6963-3  1063-6919
# 14               None  0899-7667
# 15               None  1558-2256
# 16               None  2168-2909
# 17               None  1558-366X
# 18  978-1-4673-8852-8  1063-6919
# 19               None  1939-3539
# 20  978-1-4799-5118-5  1063-6919
# 21  978-1-5386-0458-8  1063-6919
# 22               None  1939-3539
# 23               None  1939-3539
# 24  978-1-4673-8390-5  2380-7504
#
#                                              abstract  \
# 0   Deeper neural networks are more difficult to t...
# 1   The history of the development of statistical ...
# 2   A concept for the optimization of nonlinear fu...
# 3   Objective methods for assessing perceptual ima...
# 4   Multi-objective evolutionary algorithms (MOEAs...
# 5   Multilayer neural networks trained with the ba...
# 6   We propose a deep convolutional neural network...
# 7   The explosion of image data on the Internet ha...
# 8   Suppose x is an unknown vector in Ropfm (a dig...
# 9   This paper describes a computational approach ...
# 10  We study the question of feature sets for robu...
# 11  Multiresolution representations are effective ...
# 12  Texture is one of the important characteristic...
# 13  Convolutional networks are powerful visual mod...
# 14  Learning to store information over extended ti...
# 15  This tutorial provides an overview of the basi...
# 16  A mathematical tool to build a fuzzy model of ...
# 17  Matplotlib is a 2D graphics package used for P...
# 18  We present YOLO, a new approach to object dete...
# 19  State-of-the-art object detection networks dep...
# 20  Object detection performance, as measured on t...
# 21  Recent work has shown that convolutional netwo...
# 22  We make an analogy between images and statisti...
# 23  The authors describe a general-purpose, repres...
# 24  This paper proposes a Fast Region-based Convol...
#
#                                          html_url  \
# 0   https://ieeexplore.ieee.org/document/7780459/
# 1   https://ieeexplore.ieee.org/document/1100705/
# 2    https://ieeexplore.ieee.org/document/488968/
# 3   https://ieeexplore.ieee.org/document/1284395/
# 4    https://ieeexplore.ieee.org/document/996017/
# 5    https://ieeexplore.ieee.org/document/726791/
# 6   https://ieeexplore.ieee.org/document/7298594/
# 7   https://ieeexplore.ieee.org/document/5206848/
# 8   https://ieeexplore.ieee.org/document/1614066/
# 9   https://ieeexplore.ieee.org/document/4767851/
# 10  https://ieeexplore.ieee.org/document/1467360/
# 11   https://ieeexplore.ieee.org/document/192463/
# 12  https://ieeexplore.ieee.org/document/4309314/
# 13  https://ieeexplore.ieee.org/document/7298965/
# 14  https://ieeexplore.ieee.org/document/6795963/
# 15    https://ieeexplore.ieee.org/document/18626/
# 16  https://ieeexplore.ieee.org/document/6313399/
# 17  https://ieeexplore.ieee.org/document/4160265/
# 18  https://ieeexplore.ieee.org/document/7780460/
# 19  https://ieeexplore.ieee.org/document/7485869/
# 20  https://ieeexplore.ieee.org/document/6909475/
# 21  https://ieeexplore.ieee.org/document/8099726/
# 22  https://ieeexplore.ieee.org/document/4767596/
# 23   https://ieeexplore.ieee.org/document/121791/
# 24  https://ieeexplore.ieee.org/document/7410526/
#
#                                     publication_title  publication_year
# 0   2016 IEEE Conference on Computer Vision and Pa...              2016
# 1              IEEE Transactions on Automatic Control              1974
# 2   Proceedings of ICNN'95 - International Confere...              1995
# 3               IEEE Transactions on Image Processing              2004
# 4       IEEE Transactions on Evolutionary Computation              2002
# 5                             Proceedings of the IEEE              1998
# 6   2015 IEEE Conference on Computer Vision and Pa...              2015
# 7   2009 IEEE Conference on Computer Vision and Pa...              2009
# 8             IEEE Transactions on Information Theory              2006
# 9   IEEE Transactions on Pattern Analysis and Mach...              1986
# 10  2005 IEEE Computer Society Conference on Compu...              2005
# 11  IEEE Transactions on Pattern Analysis and Mach...              1989
# 12  IEEE Transactions on Systems, Man, and Cyberne...              1973
# 13  2015 IEEE Conference on Computer Vision and Pa...              2015
# 14                                 Neural Computation              1997
# 15                            Proceedings of the IEEE              1989
# 16  IEEE Transactions on Systems, Man, and Cyberne...              1985
# 17                 Computing in Science & Engineering              2007
# 18  2016 IEEE Conference on Computer Vision and Pa...              2016
# 19  IEEE Transactions on Pattern Analysis and Mach...              2017
# 20  2014 IEEE Conference on Computer Vision and Pa...              2014
# 21  2017 IEEE Conference on Computer Vision and Pa...              2017
# 22  IEEE Transactions on Pattern Analysis and Mach...              1984
# 23  IEEE Transactions on Pattern Analysis and Mach...              1992
# 24  2015 IEEE International Conference on Computer...              2015
